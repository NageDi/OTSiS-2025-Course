# %% [markdown]
# # 📡 Лабораторная работа №1: Основы сигналов
# **Цель:** Научиться генерировать сигналы.

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8')
print('Готово!')

# %% [markdown]
# ## 🛠 ЗАДАНИЕ
# Сгенерируйте сигнал $x(t) = e^{-3t} \cos(20 \pi t)$

# %%
# ВАШ КОД ЗДЕСЬ
